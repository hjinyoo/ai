# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render li, div.text_cell_render p, code{font-size:22pt; line-height:40px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render li, div.text_cell_render p, code{font-size:22pt; line-height:40px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 install 및 환경변수 load)
# - pip install langchain_upstage

# %%
# %pip install -q langchain-upstage --no-warn-script-location
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 OpenAI SDK를 사용

# %%
from openai import OpenAI # 2.9.0
import os
client = OpenAI(
    api_key=os.getenv("UPSTAGE_API_KEY"),
    base_url="https://api.upstage.ai/v1"
)

# %%
response = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {"role":"system", "content":"너는 친절하게 대답해 주는 비서야"},
        {"role":"user", "content":"2020년 월드 시리즈 누가 우승했어?"}
    ],
    temperature=0.5,
    stream=False
)

# %%
print(response.choices[0].message.content)
# Out:
# 2020년 월드 시리즈에서는 **로스앤젤레스 다저스**가 우승했습니다! 🏆
#
# 다저스는 탬파베이 레이스를 4승 2패로 꺾고, 32년 만에 통산 28번째 월드 시리즈 타이틀을 차지했습니다. 특히 이 해는 코로나19 영향으로 단축 시즌(60경기)으로 진행되었지만, 다저스는 강력한 투수진과 타선으로 압도적인 모습을 보였습니다.
#
# - **MVP**: 다저스의 불펜 투수 **코리 시거**(Corey Seager)가 시리즈 MVP를 수상했습니다.
# - **특이사항**: 다저스는 1988년 이후 32년 만에 우승을 달성하며 오랜 갈증을 해소했고, 코로나 시국 속에서 열린 첫 월드 시리즈로 기록되었습니다.
#
# 혹시 더 궁금한 점이 있다면 언제든 물어보세요! 😊

# %% [markdown]
# ## 2.2 LangChain 선택
# - 발급 받은 API KEY를 "UPSTAGE_API_KEY"라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content = "너는 친절하게 대답해 주는 비서야"),
    HumanMessage(content = "2020년 월드 시리즈 누가 우승했어?")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 그들의 7번째 월드 시리즈 우승 타이틀이며, 마지막 우승은 1988년이었습니다. 시리즈는 코로나19 팬데믹으로 인해 10월에 시작되어 11월까지 진행되었고, 다저스는 탬파베이 레이스를 4승 2패로 이겼습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 36, 'total_tokens': 121, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '4231a947-e570-4eda-a19d-238371998c35', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b96e3-35b2-7e33-99fc-76bf7b7cdfac-0', usage_metadata={'input_tokens': 36, 'output_tokens': 85, 'total_tokens': 121, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 그들의 7번째 월드 시리즈 우승 타이틀이며, 마지막 우승은 1988년이었습니다. 시리즈는 코로나19 팬데믹으로 인해 10월에 시작되어 11월까지 진행되었고, 다저스는 탬파베이 레이스를 4승 2패로 이겼습니다.'

# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, div.text_cell_render ol li p, code{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, div.text_cell_render ol li p, code{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch4_RNN(RecurrentNeuralNetwork;순환신경망)</span>
# - 데이터의 순서가 중요하거나, 시계열 데이터일 경우
# - 활용분야 : 번역, 음성인식, 주가예측, 농수산물가격예측
# #  1. 문맥을 이용하여 모델만들기

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""
text1 = "겨울이 오는 날"

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text, text1])
encoded = t.texts_to_sequences([text, text1])
print(encoded)
print(t.word_index)
# Out:
# [[3, 4, 1, 5, 6, 7, 1, 8, 9, 1, 10, 2, 1, 11], [12, 2, 13]]
# {'말이': 1, '오는': 2, '경마장에': 3, '있는': 4, '뛰고': 5, '있다': 6, '그의': 7, '법이다': 8, '가는': 9, '고와야': 10, '곱다': 11, '겨울이': 12, '날': 13}

# %%
t.texts_to_sequences(['경마장에 있는 말이 뛴다'])[0]
# Out:
# [3, 4, 1]

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])[0]
print(encoded)
print(t.word_index)
# Out:
# [2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# text를 학습시키기 위해, ['경마장에 있는'(2,3), '경마장에 있는 말이'(2,3,1), .....]
sequences = []
for line in text.split('\n'):
    encoded = t.texts_to_sequences([line])[0]
    print('원문장:', line, ', encoded된 문장:',encoded)
    for i in range(0, len(encoded)-1): # 시작index
        for j in range(i+2, len(encoded)+1): # 끝나는 index+1
            sequences.append(encoded[i:j])
#sequences, len(sequences)
print('sequences와 해석')
for sequence in sequences:
    # print(sequence)
    for word_seq in sequence:
        for key, value in t.word_index.items():
            if word_seq==value:
                print("{}:{}".format(word_seq, key), end=' ')
                break
    print()
# Out:
# 원문장: 경마장에 있는 말이 뛰고 있다 , encoded된 문장: [2, 3, 1, 4, 5]
# 원문장: 그의 말이 법이다 , encoded된 문장: [6, 1, 7]
# 원문장: 가는 말이 고와야 오는 말이 곱다 , encoded된 문장: [8, 1, 9, 10, 1, 11]
# sequences와 해석
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
sequences
# Out:
# [[2, 3],
#  [2, 3, 1],
#  [2, 3, 1, 4],
#  [2, 3, 1, 4, 5],
#  [3, 1],
#  [3, 1, 4],
#  [3, 1, 4, 5],
#  [1, 4],
#  [1, 4, 5],
#  [4, 5],
#  [6, 1],
#  [6, 1, 7],
#  [1, 7],
#  [8, 1],
#  [8, 1, 9],
#  [8, 1, 9, 10],
#  [8, 1, 9, 10, 1],
#  [8, 1, 9, 10, 1, 11],
#  [1, 9],
#  [1, 9, 10],
#  [1, 9, 10, 1],
#  [1, 9, 10, 1, 11],
#  [9, 10],
#  [9, 10, 1],
#  [9, 10, 1, 11],
#  [10, 1],
#  [10, 1, 11],
#  [1, 11]]

# %%
my_len = max([len(sequence) for sequence in sequences])
my_len
# Out:
# 6

# %%
# sequences를 훈련가능하도록 6(my_len)개열로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                #padding='post' 
                                padding='pre') # 상황에 맞게 특별한 규칙은 없음
type(padded_sequences), padded_sequences.shape, padded_sequences
# Out:
# (numpy.ndarray,
#  (28, 6),
#  array([[ 0,  0,  0,  0,  2,  3],
#         [ 0,  0,  0,  2,  3,  1],
#         [ 0,  0,  2,  3,  1,  4],
#         [ 0,  2,  3,  1,  4,  5],
#         [ 0,  0,  0,  0,  3,  1],
#         [ 0,  0,  0,  3,  1,  4],
#         [ 0,  0,  3,  1,  4,  5],
#         [ 0,  0,  0,  0,  1,  4],
#         [ 0,  0,  0,  1,  4,  5],
#         [ 0,  0,  0,  0,  4,  5],
#         [ 0,  0,  0,  0,  6,  1],
#         [ 0,  0,  0,  6,  1,  7],
#         [ 0,  0,  0,  0,  1,  7],
#         [ 0,  0,  0,  0,  8,  1],
#         [ 0,  0,  0,  8,  1,  9],
#         [ 0,  0,  8,  1,  9, 10],
#         [ 0,  8,  1,  9, 10,  1],
#         [ 8,  1,  9, 10,  1, 11],
#         [ 0,  0,  0,  0,  1,  9],
#         [ 0,  0,  0,  1,  9, 10],
#         [ 0,  0,  1,  9, 10,  1],
#         [ 0,  1,  9, 10,  1, 11],
#         [ 0,  0,  0,  0,  9, 10],
#         [ 0,  0,  0,  9, 10,  1],
#         [ 0,  0,  9, 10,  1, 11],
#         [ 0,  0,  0,  0, 10,  1],
#         [ 0,  0,  0, 10,  1, 11],
#         [ 0,  0,  0,  0,  1, 11]]))

# %%
# 독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
X.shape, y.shape
# Out:
# ((28, 5), (28,))

# %%
# 단어 갯수
vocab_size = len(t.word_index)
# X를 임베딩작업을 할 때 input_dim
input_dim = vocab_size + 1
input_dim
# Out:
# 12

# %%
# 타겟변수(y)의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, vocab_size+1)
#Y

# %%
X.shape, Y.shape, vocab_size
# Out:
# ((28, 5), (28, 12), 11)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# 2. 모델 생성하기
model = Sequential()
# 원핫인코딩한 희소행렬을 임베딩 벡터로 변환(X=[0,8,1,9,10])
model.add(Embedding(input_dim=vocab_size+1,  # 임베딩층의 입력(원핫인코딩 dim)
                    output_dim=10,           # 임베딩층의 출력
                    input_length=X.shape[1])) # 입력 데이터 길이
model.add(SimpleRNN(32))
model.add(Dense(12, activation='softmax'))
model.summary()
# 두번째 layer의 파라미터 1376 = (10+32)*32 + 32(bias) 
# 3. 모델 학습 설정
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 10)             120
#
#  simple_rnn (SimpleRNN)      (None, 32)                1376
#
#  dense (Dense)               (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 1/1 - 1s - loss: 2.4868 - accuracy: 0.1071 - 1s/epoch - 1s/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4745 - accuracy: 0.1786 - 9ms/epoch - 9ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4622 - accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4498 - accuracy: 0.2857 - 3ms/epoch - 3ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4372 - accuracy: 0.2857 - 0s/epoch - 0s/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4243 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4110 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.3972 - accuracy: 0.2857 - 0s/epoch - 0s/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.3829 - accuracy: 0.3214 - 11ms/epoch - 11ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.3680 - accuracy: 0.3571 - 2ms/epoch - 2ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.3525 - accuracy: 0.3571 - 0s/epoch - 0s/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3363 - accuracy: 0.3571 - 9ms/epoch - 9ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.3194 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.3018 - accuracy: 0.3571 - 228us/epoch - 228us/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.2834 - accuracy: 0.3571 - 8ms/epoch - 8ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.2644 - accuracy: 0.3571 - 2ms/epoch - 2ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.2448 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.2245 - accuracy: 0.3571 - 0s/epoch - 0s/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.2037 - accuracy: 0.3571 - 9ms/epoch - 9ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.1826 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.1612 - accuracy: 0.3214 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.1397 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.1185 - accuracy: 0.3214 - 3ms/epoch - 3ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.0976 - accuracy: 0.3214 - 3ms/epoch - 3ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.0775 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.0582 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.0401 - accuracy: 0.3214 - 2ms/epoch - 2ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.0232 - accuracy: 0.3214 - 0s/epoch - 0s/step
# Epoch 29/300
# 1/1 - 0s - loss: 2.0078 - accuracy: 0.3214 - 10ms/epoch - 10ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 1.9937 - accuracy: 0.3214 - 7ms/epoch - 7ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 1.9810 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 1.9693 - accuracy: 0.3214 - 3ms/epoch - 3ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 1.9585 - accuracy: 0.3214 - 0s/epoch - 0s/step
# Epoch 34/300
# 1/1 - 0s - loss: 1.9483 - accuracy: 0.3214 - 9ms/epoch - 9ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 1.9385 - accuracy: 0.2857 - 3ms/epoch - 3ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 1.9288 - accuracy: 0.2857 - 3ms/epoch - 3ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.9192 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.9095 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.8999 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.8903 - accuracy: 0.3214 - 0s/epoch - 0s/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.8808 - accuracy: 0.3214 - 9ms/epoch - 9ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.8716 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.8628 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8543 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.8463 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.8385 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.8311 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.8238 - accuracy: 0.3571 - 0s/epoch - 0s/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.8167 - accuracy: 0.3929 - 12ms/epoch - 12ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.8095 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.8022 - accuracy: 0.3929 - 7ms/epoch - 7ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.7947 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.7871 - accuracy: 0.3929 - 7ms/epoch - 7ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.7793 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.7713 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.7630 - accuracy: 0.3929 - 3ms/epoch - 3ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.7546 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.7460 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.7371 - accuracy: 0.3929 - 3ms/epoch - 3ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.7281 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.7189 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.7095 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.6998 - accuracy: 0.4643 - 7ms/epoch - 7ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.6899 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.6797 - accuracy: 0.4643 - 0s/epoch - 0s/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.6693 - accuracy: 0.4643 - 11ms/epoch - 11ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.6587 - accuracy: 0.4643 - 2ms/epoch - 2ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.6477 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.6365 - accuracy: 0.4643 - 7ms/epoch - 7ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.6250 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.6133 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.6013 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.5890 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.5765 - accuracy: 0.4643 - 0s/epoch - 0s/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.5638 - accuracy: 0.5000 - 12ms/epoch - 12ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.5509 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.5378 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.5246 - accuracy: 0.5357 - 6ms/epoch - 6ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.5112 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.4976 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.4840 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.4702 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.4564 - accuracy: 0.5357 - 0s/epoch - 0s/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.4425 - accuracy: 0.5357 - 8ms/epoch - 8ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.4285 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.4145 - accuracy: 0.5357 - 2ms/epoch - 2ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.4004 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.3863 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.3722 - accuracy: 0.5714 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.3582 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.3441 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.3302 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.3163 - accuracy: 0.6071 - 2ms/epoch - 2ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.3025 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.2888 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.2752 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.2618 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.2484 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.2353 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.2222 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.2093 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.1966 - accuracy: 0.6071 - 2ms/epoch - 2ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.1840 - accuracy: 0.6429 - 6ms/epoch - 6ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.1715 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.1593 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.1471 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.1352 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.1234 - accuracy: 0.6429 - 0s/epoch - 0s/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.1117 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.1002 - accuracy: 0.6786 - 0s/epoch - 0s/step
# Epoch 111/300
# 1/1 - 0s - loss: 1.0889 - accuracy: 0.6786 - 12ms/epoch - 12ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 1.0777 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 1.0666 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 1.0557 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 1.0449 - accuracy: 0.6786 - 2ms/epoch - 2ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 1.0343 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 1.0238 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 1.0134 - accuracy: 0.6786 - 2ms/epoch - 2ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 1.0032 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.9931 - accuracy: 0.6786 - 7ms/epoch - 7ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9831 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.9732 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.9635 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.9539 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.9444 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.9350 - accuracy: 0.7143 - 0s/epoch - 0s/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.9257 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.9165 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.9075 - accuracy: 0.7143 - 0s/epoch - 0s/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.8985 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8896 - accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8809 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8722 - accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.8637 - accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.8553 - accuracy: 0.7857 - 6ms/epoch - 6ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.8469 - accuracy: 0.7857 - 6ms/epoch - 6ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.8387 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.8305 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.8225 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.8145 - accuracy: 0.7857 - 2ms/epoch - 2ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.8066 - accuracy: 0.7857 - 1ms/epoch - 1ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7988 - accuracy: 0.7857 - 7ms/epoch - 7ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7912 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7836 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7760 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7686 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.7613 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.7540 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.7469 - accuracy: 0.7857 - 6ms/epoch - 6ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.7398 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.7328 - accuracy: 0.7857 - 0s/epoch - 0s/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.7259 - accuracy: 0.7857 - 7ms/epoch - 7ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.7191 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.7124 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.7057 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.6991 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6926 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6862 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6798 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6736 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.6674 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.6613 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.6552 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.6493 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.6434 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.6376 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.6318 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.6262 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.6206 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.6150 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.6096 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.6042 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.5989 - accuracy: 0.8929 - 10ms/epoch - 10ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.5936 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.5884 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.5833 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5782 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5732 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5683 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.5634 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.5586 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.5539 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.5492 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.5446 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5400 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5355 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5310 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5266 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.5223 - accuracy: 0.8929 - 10ms/epoch - 10ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.5180 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.5137 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.5096 - accuracy: 0.8929 - 10ms/epoch - 10ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.5054 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.5014 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.4973 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.4934 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.4894 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.4856 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.4817 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.4780 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.4742 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4706 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4669 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4633 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4598 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4563 - accuracy: 0.8929 - 9ms/epoch - 9ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4529 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4495 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4461 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4428 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4395 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4363 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4331 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4299 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4268 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4238 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4207 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4178 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4148 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4119 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4090 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.4062 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.4034 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.4007 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.3980 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.3953 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.3927 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.3901 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.3875 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.3850 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3825 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3800 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3776 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3752 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3728 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3705 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3682 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3660 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3637 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3615 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3594 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3573 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3552 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3531 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3511 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3491 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3471 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3451 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3432 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3413 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3395 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3376 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3358 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3341 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3323 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3306 - accuracy: 0.8929 - 1ms/epoch - 1ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3289 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3272 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3256 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3240 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3224 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3208 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3193 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3177 - accuracy: 0.8929 - 10ms/epoch - 10ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3162 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3148 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3133 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3119 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3105 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3091 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3077 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3064 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3051 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3038 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3025 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3012 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3000 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.2987 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.2975 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.2964 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.2952 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.2940 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.2929 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2918 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.2907 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.2896 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.2886 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.2875 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.2865 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.2855 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2845 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2835 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2825 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2816 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2806 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2797 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2788 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2779 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2770 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2762 - accuracy: 0.8929 - 3ms/epoch - 3ms/step

# %%
# 5. 모델 평가
# 학습과정 표시하기
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(10,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax 생성
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(bbox_to_anchor=(0.955, 0.7))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 6. 모델 사용하기(경마장에 -> 있는)
encoded = t.texts_to_sequences(['경마장에 있는 말이'])[0]
input_data = pad_sequences([encoded], maxlen=5, padding='pre')
result = model.predict(input_data, verbose=0).argmax()
print('모델이 예측 결과 :', result)
for key, value in t.word_index.items():
    if value==result:
        print('예측한 단어 :', key)
        break
# Out:
# 모델이 예측 결과 : 4
# 예측한 단어 : 뛰고

# %%
encoded = t.texts_to_sequences(['봄은'])[0]
print('숫자로 바꾼 겨울은 :', encoded)
input_data = pad_sequences([encoded], maxlen=5, padding='pre')
print('모델에 입력할 내용 :', input_data)
# Out:
# 숫자로 바꾼 겨울은 : []
# 모델에 입력할 내용 : [[0 0 0 0 0]]

# %%
# 6. 모델 사용하기(사용자로부터 입력받은 문자 -> ?)
word = input('입력단어는 ?')
encoded = t.texts_to_sequences([word])[0]
input_data = pad_sequences([encoded], maxlen=5, padding='pre')
result = model.predict(input_data, verbose=0).argmax()
print('모델이 예측 결과 :', result)
for key, value in t.word_index.items():
    if value==result:
        print('예측한 단어 :', key)
        break
# Out:
# 입력단어는 ?경마장에
# 모델이 예측 결과 : 3
# 예측한 단어 : 있는

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# "경마장에" 이후에 단어 4개의 문맥을 만들어줘
def sentence_generation(model, current_word, n):
    for i in range(1, n+1):
        print(i, '번째 current_word :', current_word)
        encoded = t.texts_to_sequences([current_word])
        input_data = pad_sequences(encoded, maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        for word, index in t.word_index.items():
            if result==index:
                print("{}번째 예측 {} : {}".format(i, result, word))
                current_word = current_word + ' ' + word
                break # 안의 for문 break

# %%
sentence_generation(model, "경마장에", 4)
# Out:
# 1 번째 current_word : 경마장에
# 1번째 예측 3 : 있는
# 2 번째 current_word : 경마장에 있는
# 2번째 예측 1 : 말이
# 3 번째 current_word : 경마장에 있는 말이
# 3번째 예측 4 : 뛰고
# 4 번째 current_word : 경마장에 있는 말이 뛰고
# 4번째 예측 5 : 있다

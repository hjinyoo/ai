# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render ul li{font-size:22pt; line-height:30px;}
div.output {font-size:22pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:22pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render ul li{font-size:22pt; line-height:30px;}
# div.output {font-size:22pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:22pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성
from tensorflow.keras.layers import Input, Dense # 모델 layer 쌓을 떄 사용
import matplotlib.pyplot as plt

# %%
# 1. data set
x_data = np.array([[0,0],
                   [0,1],
                   [1,0],
                   [1,1]])
y_data = np.array([[0],[1],[1],[0]])
# 2. 모델 구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10, # 출력 갯수
                input_dim=2, # input_shape = (2,) # 입력갯수
                activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu')) # 은닉층에서는 input_shape는 x
model.add(Dense(10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
    # loss : mae(회귀분석), binary_crossentropy(이진분류=로지스틱회귀분석),
            # categorical_crossentropy(다중분류-원핫인코딩을 한 경우)
            # sparse_categorical_crossentropy(다중분류-원핫인코딩을 안 한 경우)
model.compile(loss = 'binary_crossentropy', # 손실함수(loss function)          
               optimizer='adam', 
               metrics=['binary_accuracy']) # 2진분류
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 20)                220
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist = model.fit(x_data,y_data,epochs=300,verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 0s - loss: 0.7022 - binary_accuracy: 0.5000 - 372ms/epoch - 372ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.6997 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.6972 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.6948 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6925 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6901 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6879 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6856 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6835 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6816 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6797 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6784 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6770 - binary_accuracy: 0.5000 - 12ms/epoch - 12ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6757 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6745 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6732 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6719 - binary_accuracy: 0.5000 - 12ms/epoch - 12ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6703 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6685 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6667 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6649 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6630 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6612 - binary_accuracy: 0.5000 - 1ms/epoch - 1ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6594 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6575 - binary_accuracy: 0.5000 - 10ms/epoch - 10ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6556 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6538 - binary_accuracy: 0.5000 - 1ms/epoch - 1ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6519 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6499 - binary_accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6480 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6461 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6441 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6423 - binary_accuracy: 0.5000 - 12ms/epoch - 12ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6404 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6385 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6365 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6345 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6326 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6306 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6287 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6268 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.6251 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.6233 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.6216 - binary_accuracy: 0.5000 - 10ms/epoch - 10ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.6198 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.6179 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.6160 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.6139 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.6120 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.6101 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.6081 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.6060 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.6039 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.6019 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.5999 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.5979 - binary_accuracy: 0.5000 - 1ms/epoch - 1ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.5958 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.5937 - binary_accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.5916 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.5895 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.5875 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.5855 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.5835 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.5815 - binary_accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.5794 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.5773 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.5752 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.5732 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.5710 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.5689 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.5668 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.5647 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.5625 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.5605 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.5584 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.5563 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.5542 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.5520 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.5498 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.5478 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.5456 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.5434 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.5413 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.5390 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.5368 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.5347 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.5325 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.5304 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.5283 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.5261 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.5238 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.5216 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.5193 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.5171 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.5149 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.5127 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.5104 - binary_accuracy: 1.0000 - 999us/epoch - 999us/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.5083 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.5063 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.5042 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.5021 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 0.4999 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 0.4977 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 104/300
# 1/1 - 0s - loss: 0.4955 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 105/300
# 1/1 - 0s - loss: 0.4934 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 0.4912 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 0.4889 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 108/300
# 1/1 - 0s - loss: 0.4867 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 109/300
# 1/1 - 0s - loss: 0.4844 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.4824 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.4802 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.4782 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.4761 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.4738 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.4716 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.4693 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.4672 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.4650 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.4629 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.4608 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.4587 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.4565 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.4543 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.4521 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.4500 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.4478 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.4456 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.4435 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.4414 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.4392 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.4370 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.4349 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.4328 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.4307 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.4286 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.4264 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.4243 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.4221 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.4199 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.4179 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.4157 - binary_accuracy: 1.0000 - 387us/epoch - 387us/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.4135 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.4113 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.4093 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.4071 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.4048 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.4026 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.4005 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.3982 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.3961 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.3940 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.3917 - binary_accuracy: 1.0000 - 859us/epoch - 859us/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.3894 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.3872 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.3850 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.3828 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.3806 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.3783 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.3761 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.3740 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.3718 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.3698 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.3679 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.3658 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.3636 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.3616 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.3595 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.3574 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.3553 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.3530 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.3510 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.3489 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.3468 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.3447 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.3428 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.3407 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.3387 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.3367 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.3347 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.3327 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.3307 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.3287 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.3267 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.3247 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.3227 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.3207 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.3188 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.3167 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.3147 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.3127 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.3109 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.3089 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.3069 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.3050 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.3030 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.3011 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.2991 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.2973 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.2954 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.2932 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.2914 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.2895 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.2875 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.2855 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.2837 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.2818 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.2798 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.2780 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.2761 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.2742 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.2723 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.2704 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.2685 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.2666 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.2647 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.2629 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.2611 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.2592 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.2573 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.2554 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.2537 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.2519 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.2501 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.2483 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.2464 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.2446 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.2428 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.2410 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.2391 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.2373 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.2354 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.2338 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.2320 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.2302 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.2283 - binary_accuracy: 1.0000 - 1000us/epoch - 1000us/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.2266 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.2249 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.2232 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.2214 - binary_accuracy: 1.0000 - 501us/epoch - 501us/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.2197 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.2180 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.2162 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.2145 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.2128 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.2110 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.2093 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.2077 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.2059 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.2043 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.2026 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.2010 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.1994 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.1978 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.1962 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.1945 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.1929 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.1914 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.1898 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.1882 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.1866 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.1850 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.1835 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.1819 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.1803 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.1789 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.1774 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.1758 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.1743 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.1729 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.1713 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.1698 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.1684 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.1669 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.1654 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.1640 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.1625 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.1610 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.1596 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.1582 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.1568 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.1554 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.1540 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.1526 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.1512 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.1499 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.1485 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.1471 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.1458 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.1444 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.1431 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.1418 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.1405 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.1392 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.1379 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.1366 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.1353 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.1340 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.1328 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.1316 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.1303 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step

# %%
# 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='center left')
plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data,y_data) # loss & metrics(binary accuracy)
print('loss :', score[0])
print('accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1292 - binary_accuracy: 1.0000
# loss : 0.12916211783885956
# accuracy : 1.0

# %%
# 예측하기
model.predict(np.array([[0,1]]))
# Out:
# 1/1 [==============================] - 0s 60ms/step
# array([[0.87550354]], dtype=float32)
